# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/4/4f/Twitter-logo.svg" alt="twitter_logo" width="120"/>
# <span style="float:left">
#   <span style="font-family:Helvetica; font-size:4em;">
#     <b>Twitter sentiment analysis DEV &nbsp;&nbsp;&nbsp;</b><br>
#   </span>
#   <span style="font-family:Helvetica; font-size:2em;">
#     Mounting S3 bucket
#   </span>
# </span>
# <br clear="left"/>
# <br><br><br>
# <i>Goal of this project is to develop and ML pipeline for Twitter sentiment analysis with the end goal of hosting the ML pipeline in and ML Ops Pipeline using streaming Twitter data through the AWS architecture.</i>
# <br><br>
# This notebook is for mounting the data from my S3 bucket.

# %% [markdown]
# ## Table of contents
# #### 1. Set-up
# * 1.1 Environment
# * 1.2 User defined functions
# * 1.3 Global variables
#
# #### 2. Mounting
# * 2.1 Mount datasets
# * 2.2 Verify mounting
# <br><br>

# %% [markdown]
# ## 1. Set-up

# %% [markdown]
# #### 1.1 Environment

# %%
# no modules to import for mounting
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# #### 1.2 User defined functions

# %%
# Function mounts new or existing S3 bucket to our DataBricks environment under /mnt
def mount_s3_bucket(access_key, secret_key, bucket_name, mount_folder):
    encoded_secret_key = secret_key.replace("/", "%2F")
    
    print ("Mounting", bucket_name)
    
    try:
        # Unmount the data in case it was already mounted.
        dbutils.fs.unmount(f"/mnt/{mount_folder}")
        
    except:
        # If it fails to unmount it most likely wasn't mounted in the first place
        print ("Directory not unmounted: ", mount_folder)
    
    finally:
        # Lastly, mount our bucket.
        dbutils.fs.mount(f"s3a://{access_key}:{encoded_secret_key}@{bucket_name}" , f"/mnt/{mount_folder}")
        #dbutils.fs.mount("s3a://"+ ACCESS_KEY_ID + ":" + ENCODED_SECRET_KEY + "@" + bucket_name, mount_folder)
        print ("The bucket", bucket_name, "was mounted to", mount_folder, "\n")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# #### 1.3 Global variables

# %%
# S3 bucket location for data import
S3_BUCKET_NAME = r'lambda-epl-output'
S3_IMPORT_FOLDER = r'twitter_stream/*'
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ## 2. Mounting

# %% [markdown]
# #### 2.1 Mount datasets

# %%
ACCESS_KEY_ID = r'ACCESS KEY ID HERE'
SECRET_KEY = r'SECRET KEY HERE'
encoded_secret_key = SECRET_KEY.replace("/", "%2F")
aws_bucket_name = "lambda-epl-output"
mount_name = "lambda-epl-output"

dbutils.fs.mount(f"s3a://{ACCESS_KEY_ID}:{encoded_secret_key}@{aws_bucket_name}", f"/mnt/{mount_name}")
display(dbutils.fs.ls(f"/mnt/{mount_name}"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/mnt/lambda-epl-output/twitter_stream/</td><td>twitter_stream/</td><td>0</td><td>1654056902384</td></tr></tbody></table></div>

# %%
display(dbutils.fs.ls(f"/mnt/{mount_name}/twitter_stream/2022/05"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/mnt/lambda-epl-output/twitter_stream/2022/05/25/</td><td>25/</td><td>0</td><td>1654056913318</td></tr><tr><td>dbfs:/mnt/lambda-epl-output/twitter_stream/2022/05/26/</td><td>26/</td><td>0</td><td>1654056913318</td></tr><tr><td>dbfs:/mnt/lambda-epl-output/twitter_stream/2022/05/27/</td><td>27/</td><td>0</td><td>1654056913318</td></tr><tr><td>dbfs:/mnt/lambda-epl-output/twitter_stream/2022/05/28/</td><td>28/</td><td>0</td><td>1654056913318</td></tr><tr><td>dbfs:/mnt/lambda-epl-output/twitter_stream/2022/05/29/</td><td>29/</td><td>0</td><td>1654056913318</td></tr><tr><td>dbfs:/mnt/lambda-epl-output/twitter_stream/2022/05/30/</td><td>30/</td><td>0</td><td>1654056913318</td></tr><tr><td>dbfs:/mnt/lambda-epl-output/twitter_stream/2022/05/31/</td><td>31/</td><td>0</td><td>1654056913318</td></tr></tbody></table></div>

# %%
mount_s3_bucket(ACCESS_KEY_ID, SECRET_KEY, S3_BUCKET_NAME, S3_IMPORT_FOLDER)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Mounting lambda-epl-output
# Directory not unmounted:  twitter_stream/*
# The bucket lambda-epl-output was mounted to twitter_stream/*
#
# </div>

# %% [markdown]
# #### 2.2 Verify mounting

# %%
dbutils.fs.ls("/mnt/lambda-epl-output/twitter_stream/2022")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[7]: [FileInfo(path=&#39;dbfs:/mnt/lambda-epl-output/twitter_stream/2022/05/&#39;, name=&#39;05/&#39;, size=0, modificationTime=1654056935825),
#  FileInfo(path=&#39;dbfs:/mnt/lambda-epl-output/twitter_stream/2022/06/&#39;, name=&#39;06/&#39;, size=0, modificationTime=1654056935825)]</div>

# %%
twitter = (spark.read
           .option('header','false')
           .option("recursiveFileLookup","true")
           .option('inferSchema','false')
           .parquet('/mnt/lambda-epl-output/twitter_stream/')
          )
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# #### 2.3 Create Delta Table

# %%
#
read_format = 'parquet'
write_format = 'delta'
load_path = '/mnt/lambda-epl-output/twitter_stream/'
save_path = '/tmp/delta/twitter_stream'
table_name = 'default.twitter_stream'

# Load the data from its source.
tweets = (spark
            .read
            .option('header','false')
            .option('recursiveFileLookup','true')
            .option('inferSchema','false')
            .parquet(load_path)
)
# Write the data to its target.
tweets.write \
  .format(write_format) \
  .save(save_path)

# Create the table.
spark.sql(f"CREATE TABLE {table_name} USING DELTA LOCATION '{save_path}'")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[9]: DataFrame[]</div>

# %% [markdown]
# #### 2.4 Optimize delta table

# %%
spark.sql("OPTIMIZE delta.`/tmp/delta/twitter_stream`")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[10]: DataFrame[path: string, metrics: struct&lt;numFilesAdded:bigint,numFilesRemoved:bigint,filesAdded:struct&lt;min:bigint,max:bigint,avg:double,totalFiles:bigint,totalSize:bigint&gt;,filesRemoved:struct&lt;min:bigint,max:bigint,avg:double,totalFiles:bigint,totalSize:bigint&gt;,partitionsOptimized:bigint,zOrderStats:struct&lt;strategyName:string,inputCubeFiles:struct&lt;num:bigint,size:bigint&gt;,inputOtherFiles:struct&lt;num:bigint,size:bigint&gt;,inputNumCubes:bigint,mergedFiles:struct&lt;num:bigint,size:bigint&gt;,numOutputCubes:bigint,mergedNumCubes:bigint&gt;,numBatches:bigint,totalConsideredFiles:bigint,totalFilesSkipped:bigint,preserveInsertionOrder:boolean&gt;]</div>
